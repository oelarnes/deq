# %%
from ipy import *
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %load_ext autoreload
# %autoreload 2

# %%
res = all_metrics_analysis()
# Out:
# 2025-01-09 23:24:22,474 - root - INFO - Calculating agg df for PIO
# 2025-01-09 23:24:22,766 - root - INFO - Cache c517d67c74437f7bcfb3e67e45202051 found
# 2025-01-09 23:24:22,768 - root - INFO - Calculating agg df for FDN
# 2025-01-09 23:24:23,127 - root - INFO - Cache c46629316d2676a24917fd8e3bf54efa found
# 2025-01-09 23:24:23,128 - root - INFO - Calculating agg df for DSK
# 2025-01-09 23:24:23,567 - root - INFO - Cache 4bcf50c630cce7afc0c947beed87eba9 found
# 2025-01-09 23:24:23,568 - root - INFO - Calculating agg df for BLB
# 2025-01-09 23:24:23,920 - root - INFO - Cache 726ebfe75bcfbb712d3c7a35a1386191 found
# 2025-01-09 23:24:23,921 - root - INFO - Calculating agg df for MH3
# 2025-01-09 23:24:24,377 - root - INFO - Cache ee448993db4083ae292c47da3d956843 found
# 2025-01-09 23:24:24,378 - root - INFO - Calculating agg df for OTJ
# 2025-01-09 23:24:25,195 - root - INFO - Cache 85a651461c1366238df939dfd9b2b441 found
# 2025-01-09 23:24:25,195 - root - INFO - Calculating agg df for MKM
# 2025-01-09 23:24:25,675 - root - INFO - Cache e366828f51951246b683602d8eca0ea6 found
# 2025-01-09 23:24:25,676 - root - INFO - Calculating agg df for KTK
# 2025-01-09 23:24:25,817 - root - INFO - Cache a5ab598115f7c7c11950a3ec5dcc5d8d found
# 2025-01-09 23:24:25,818 - root - INFO - Calculating agg df for LCI
# 2025-01-09 23:24:26,222 - root - INFO - Cache b016bd329c83a0f4e03c252f1f8aca33 found
# 2025-01-09 23:24:26,223 - root - INFO - Calculating agg df for WOE
# 2025-01-09 23:24:26,766 - root - INFO - Cache f557d53290c40a5461b3d23e52cb054e found
# 2025-01-09 23:24:26,767 - root - INFO - Calculating agg df for LTR
# 2025-01-09 23:24:27,152 - root - INFO - Cache 203299159f511537a4e1513491a1c992 found
# 2025-01-09 23:24:27,153 - root - INFO - Calculating agg df for MOM
# 2025-01-09 23:24:27,920 - root - INFO - Cache 25a8bfe7d0491f6005e3e2081d94b665 found
# 2025-01-09 23:24:27,921 - root - INFO - Calculating agg df for ONE
# 2025-01-09 23:24:28,187 - root - INFO - Cache 1ecc432f1368c2621599e1b62a9a7df7 found
# 2025-01-09 23:24:28,188 - root - INFO - Calculating agg df for BRO
# 2025-01-09 23:24:28,560 - root - INFO - Cache 34d5ac715cf79c1c1b5904b734e818bb found
# 2025-01-09 23:24:28,561 - root - INFO - Calculating agg df for DMU
# 2025-01-09 23:24:28,966 - root - INFO - Cache cb19e4bda27cb03b72504730ee25edca found
# 2025-01-09 23:24:28,968 - root - INFO - Calculating agg df for SNC
# 2025-01-09 23:24:29,286 - root - INFO - Cache c1a24068f9f9eaf126899e9726b297ad found
# 2025-01-09 23:24:38,494 - root - INFO - Cache 9ae767eb2438f8d7280caf38dd7fbb7e found
# 2025-01-09 23:24:38,495 - root - INFO - Calculating agg df for DMU
# 2025-01-09 23:24:38,683 - root - INFO - Cache 8d6502b02e9f9b32294eaa854202e563 found
# 2025-01-09 23:24:38,684 - root - INFO - Calculating agg df for SNC
# 2025-01-09 23:24:38,871 - root - INFO - Cache 7cd31de950d3bd542d544e6ba318f9f4 found
# 2025-01-09 23:24:38,873 - root - INFO - Calculating agg df for NEO
# 2025-01-09 23:24:39,078 - root - INFO - Cache 0828c4b18906a35c30aa1b5ed34d2ac2 found
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 res = all_metrics_analysis()
#
# File ~/dev/deq/deq/p1_strategy.py:252, in all_metrics_analysis(metric_filter, results_filter)
#     247 def all_metrics_analysis(
#     248     metric_filter: dict | None = None,
#     249     results_filter: dict | None = None,
#     250 ):
#     251     metrics = METRICS
# --> 252     metric_results = {metric: p1_strat_analysis(
#     253         all_sets,
#     254         metric,
#     255         metric_filter=metric_filter,
#     256         results_filter=results_filter,
#     257     ) for metric in metrics}
#     258     delta_dfs = [metric_results[metric].df.select(['wr_group', f"{metric}_strat_delta"]) for metric in metrics]
#     260     result_df = functools.reduce(lambda prev, curr: prev.join(curr, on="wr_group"), delta_dfs)
#
# File ~/dev/deq/deq/p1_strategy.py:252, in <dictcomp>(.0)
#     247 def all_metrics_analysis(
#     248     metric_filter: dict | None = None,
#     249     results_filter: dict | None = None,
#     250 ):
#     251     metrics = METRICS
# --> 252     metric_results = {metric: p1_strat_analysis(
#     253         all_sets,
#     254         metric,
#     255         metric_filter=metric_filter,
#     256         results_filter=results_filter,
#     257     ) for metric in metrics}
#     258     delta_dfs = [metric_results[metric].df.select(['wr_group', f"{metric}_strat_delta"]) for metric in metrics]
#     260     result_df = functools.reduce(lambda prev, curr: prev.join(curr, on="wr_group"), delta_dfs)
#
# File ~/dev/deq/deq/p1_strategy.py:193, in p1_strat_analysis(set_codes, metric, metric_filter, results_filter, card_parity, luck_control)
#     183 def p1_strat_analysis(
#     184     set_codes: list[str],
#     185     metric: str,
#    (...)
#     189     luck_control: bool = False,
#     190 ):
#     191     model_dfs = get_model_dfs(set_codes, metric, results_filter, metric_filter)
# --> 193     mapped = strategy_mapped_df(model_dfs, card_parity)
#     195     base_weight = pl.col(ColName.EVENT_MATCHES_SUM)
#     196     base_wr_df = model_dfs.wr_df.select([
#     197         'wr_group',
#     198         base_weight,
#    (...)
#     205         (pl.col('day_weight') / base_weight).alias("mean_day_picked"),
#     206     ]).sort('wr_group')
#
# File ~/dev/deq/deq/p1_strategy.py:151, in strategy_mapped_df(model_dfs, card_parity)
#     149 while iter < iter_max and len(remaining_df):
#     150     if iter > 1:
# --> 151         go_up_df = go_up_df.select(select_cols + up_one_cols)
#     152         go_down_df = go_down_df.select(select_cols + down_one_cols)
#     153     discrepancy = pl.lit(iter).alias('discrepancy')
#
# File ~/dev/deq/.venv/lib/python3.11/site-packages/polars/dataframe/frame.py:9323, in DataFrame.select(self, *exprs, **named_exprs)
#    9223 def select(
#    9224     self, *exprs: IntoExpr | Iterable[IntoExpr], **named_exprs: IntoExpr
#    9225 ) -> DataFrame:
#    9226     """
#    9227     Select columns from this DataFrame.
#    9228
#    (...)
#    9321     └──────────────┘
#    9322     """
# -> 9323     return self.lazy().select(*exprs, **named_exprs).collect(_eager=True)
#
# File ~/dev/deq/.venv/lib/python3.11/site-packages/polars/lazyframe/frame.py:2057, in LazyFrame.collect(self, type_coercion, _type_check, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, streaming, engine, background, _check_order, _eager, **_kwargs)
#    2055 # Only for testing purposes
#    2056 callback = _kwargs.get("post_opt_callback", callback)
# -> 2057 return wrap_df(ldf.collect(callback))
#
# ColumnNotFoundError: up_one_wr_mod
#
# Resolved plan until failure:
#
# 	---> FAILED HERE RESOLVING 'select' <---
# DF ["expansion", "name", "matches_per_pick", "mean_day_picked"]; PROJECT */6 COLUMNS

# %%
ax = plt.subplot()
metrics = [
    "deq_strat_delta",
    "gih_wr_strat_delta",
    "gp_wr_strat_delta",
    "pick_equity_strat_delta",    
    "iwd_strat_delta",  
]
for metric in metrics:
    ax.plot("wr_group", 
            metric, 
            data=res.df)
    

ax.legend()
ax.yaxis.set_major_formatter(
    mtick.PercentFormatter(1.0
                          ))
ax.xaxis.set_major_formatter(
    mtick.PercentFormatter(100))

ax.set_title("Effect on win rate of choosing p1p1 by metric")
ax.set_xlabel('Skill Cohort')
ax.set_ylabel('Simulated effect on match win rate')

plt.show()

# %%
ax = plt.subplot()
metrics = [
    "deq_strat_delta",
    "gih_wr_strat_delta",
    "gp_wr_strat_delta",
    "pick_equity_strat_delta",    
    "iwd_strat_delta",  
]
for metric in metrics:
    ax.plot("wr_group", 
            metric, 
            data=res.df)
    

ax.legend()
ax.yaxis.set_major_formatter(
    mtick.PercentFormatter(1.0
                          ))
ax.xaxis.set_major_formatter(
    mtick.PercentFormatter(100))

ax.set_title("Effect on win rate of choosing p1p1 by metric")
ax.set_xlabel('Skill Cohort')
ax.set_ylabel('Simulated effect on match win rate')

plt.show()

# %%
df = p1_skill_control_df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = p1_skill_control_df()
#
# NameError: name 'p1_skill_control_df' is not defined

# %%
ax = plt.subplot()
metrics = [
    "deq_strat_delta",
    "deq_base_strat_delta",
    
    "gp_wr_strat_delta",
    "gp_wr_bias_adj_strat_delta"
    ,  
]
for metric in metrics:
    ax.plot("wr_group", 
            metric, 
            data=res.df)
    

ax.legend()
ax.yaxis.set_major_formatter(
    
    mtick.PercentFormatter(1.0
                          ))
ax.xaxis.set_major_formatter(
    mtick.PercentFormatter(100))

ax.set_title("Effect on win rate of choosing p1p1 by metric")
ax.set_xlabel('Skill Cohort')
ax.set_ylabel('Simulated effect on match win rate')

plt.show()
