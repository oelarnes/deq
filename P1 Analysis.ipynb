# %%
from ipy import *
import matplotlib.pyplot as plt
import
matplotlib.ticker as mtick

# %load_ext autoreload
# %autoreload 2

# %%
res = 
all_metrics_analysis()
# Out:
# 2025-01-10 07:35:24,374 - root - INFO - Calculating agg df for PIO
# 2025-01-10 07:35:24,692 - root - INFO - Cache c517d67c74437f7bcfb3e67e45202051 found
# 2025-01-10 07:35:24,693 - root - INFO - Calculating agg df for FDN
# 2025-01-10 07:35:25,053 - root - INFO - Cache c46629316d2676a24917fd8e3bf54efa found
# 2025-01-10 07:35:25,054 - root - INFO - Calculating agg df for DSK
# 2025-01-10 07:35:25,496 - root - INFO - Cache 4bcf50c630cce7afc0c947beed87eba9 found
# 2025-01-10 07:35:25,497 - root - INFO - Calculating agg df for BLB
# 2025-01-10 07:35:25,852 - root - INFO - Cache 726ebfe75bcfbb712d3c7a35a1386191 found
# 2025-01-10 07:35:25,853 - root - INFO - Calculating agg df for MH3
# 2025-01-10 07:35:26,284 - root - INFO - Cache ee448993db4083ae292c47da3d956843 found
# 2025-01-10 07:35:26,285 - root - INFO - Calculating agg df for OTJ
# 2025-01-10 07:35:27,094 - root - INFO - Cache 85a651461c1366238df939dfd9b2b441 found
# ...

# %%
ax = plt.subplot()
metrics = [
    "deq_strat_delta",
    "gih_wr_strat_delta",
    "gp_wr_strat_delta",
    "pick_equity_strat_delta",    
    "iwd_strat_delta",  
]
for metric in metrics:
    ax.plot("wr_group", 
            metric, 
            data=res.df)
    

ax.legend()
ax.yaxis.set_major_formatter(
    mtick.PercentFormatter(1.0
                          ))
ax.xaxis.set_major_formatter(
    mtick.PercentFormatter(100))


ax.set_title("Effect on win rate of choosing p1p1 by metric")
ax.set_xlabel('Skill Cohort')
ax.set_ylabel('Simulated effect on match win rate')

plt.show()

# %%
ax = plt.subplot()
metrics = [I'm
    "deq_strat_delta",
    "gih_wr_strat_delta",
    "gp_wr_strat_delta",
    "pick_equity_strat_delta",    
    "iwd_strat_delta",  
]
for metric in metrics:
    ax.plot("wr_group", 
            metric, 
            data=res.df)
    

ax.legend()
ax.yaxis.set_major_formatter(
    mtick.PercentFormatter(1.0
                          ))
ax.xaxis.set_major_formatter(
    mtick.PercentFormatter(100))

ax.set_title("Effect on win rate of choosing p1p1 by metric")
ax.set_xlabel('Skill Cohort')
ax.set_ylabel('Simulated effect on match win rate')

plt.show()

# %%
df = p1_skill_control_df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = p1_skill_control_df()
#
# NameError: name 'p1_skill_control_df' is not defined

# %%
ax = plt.subplot()
metrics = [
    "deq_strat_delta",
    "deq_base_strat_delta",
    
    "gp_wr_strat_delta",
    "gp_wr_bias_adj_strat_delta"
    ,  
]
for metric in metrics:
    ax.plot("wr_group", 
            metric, 
            data=res.df)
    

ax.legend()
ax.yaxis.set_major_formatter(
    
    mtick.PercentFormatter(1.0
                          ))
ax.xaxis.set_major_formatter(
    mtick.PercentFormatter(100))

ax.set_title("Effect on win rate of choosing p1p1 by metric")
ax.set_xlabel('Skill Cohort')
ax.set_ylabel('Simulated effect on match win rate')

plt.show()
