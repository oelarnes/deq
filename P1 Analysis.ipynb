# %%
from ipy import *
from deq.plot import p1strat_line_plot
import matplotlib.pyplot as plt
import plotly

# %load_ext autoreload
# %autoreload 2

# %%
res = all_metrics_analysis()
# Out:
# 2025-01-12 22:34:39,249 - root - INFO - Running p1 strategy analysis for metric pick_equity
# 2025-01-12 22:34:39,250 - root - INFO - Calculation metric pick_equity value for context
# 2025-01-12 22:34:39,250 - root - INFO - Calculating agg df for MOM
# 2025-01-12 22:34:40,108 - root - INFO - Cache 25a8bfe7d0491f6005e3e2081d94b665 found
# 2025-01-12 22:34:40,109 - root - INFO - Calculating agg df for MH3
# 2025-01-12 22:34:40,553 - root - INFO - Cache ee448993db4083ae292c47da3d956843 found
# 2025-01-12 22:34:40,554 - root - INFO - Calculating agg df for BRO
# 2025-01-12 22:34:40,920 - root - INFO - Cache 34d5ac715cf79c1c1b5904b734e818bb found
# 2025-01-12 22:34:40,921 - root - INFO - Calculating agg df for WOE
# 2025-01-12 22:34:41,464 - root - INFO - Cache f557d53290c40a5461b3d23e52cb054e found
# 2025-01-12 22:34:41,465 - root - INFO - Calculating agg df for OTJ
# 2025-01-12 22:34:42,263 - root - INFO - Cache 85a651461c1366238df939dfd9b2b441 found
# ...

# %%
_ = p1strat_line_plot(res, mode='wr_delta')
plt.show()

# %%
_ = p1strat_line_plot(
    res,
    mode='misrep'
)
plt.show()

# %%
res_alt = all_metrics_analysis(
    metric_filter=EARLY_FORMAT,
    results_filter=LATE_FORMAT
)

# %%
res_alt.agg_df["deq_strat_delta"][0]
# Out:
# 0.0034899426573133056

# %%
_ = p1strat_line_plot(
    res_alt
    , 
    mode='wr_delta'
)
plt.show()

# %%
_ = p1strat_line_plot(
    res_alt
    ,
    mode='misrep'
)
plt.show()

# %%
res_alt = all_metrics_analysis(
    metric_filter=META_FILTER,
    results_filter=LATE_FORMAT
)
# Out:
# 2025-01-12 22:54:19,875 - root - INFO - Running p1 strategy analysis for metric pick_equity
# 2025-01-12 22:54:19,875 - root - INFO - Calculation metric pick_equity value for context
# 2025-01-12 22:54:19,876 - root - INFO - Calculating agg df for MOM
# 2025-01-12 22:54:19,976 - root - INFO - Cache 25a8bfe7d0491f6005e3e2081d94b665 found
# 2025-01-12 22:54:19,977 - root - INFO - Calculating agg df for MH3
# 2025-01-12 22:54:20,071 - root - INFO - Cache ee448993db4083ae292c47da3d956843 found
# 2025-01-12 22:54:20,072 - root - INFO - Calculating agg df for BRO
# 2025-01-12 22:54:20,167 - root - INFO - Cache 34d5ac715cf79c1c1b5904b734e818bb found
# 2025-01-12 22:54:20,168 - root - INFO - Calculating agg df for WOE
# 2025-01-12 22:54:20,262 - root - INFO - Cache f557d53290c40a5461b3d23e52cb054e found
# 2025-01-12 22:54:20,263 - root - INFO - Calculating agg df for OTJ
# 2025-01-12 22:54:20,372 - root - INFO - Cache 85a651461c1366238df939dfd9b2b441 found
# ...
