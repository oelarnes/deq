# %%
from IPython.display import Image, HTML

scryfall_id = "7a136f26-ac66-407f-b389-357222d2c4a2"
file_face = "front"
file_type = "large"
file_format = "jpg"
dir1 = scryfall_id[0]
dir2 = scryfall_id[1]
img_url = f"https://cards.scryfall.io/{file_type}/{file_face}/{dir1}/{dir2}/{scryfall_id}.{file_format}"
width = 150
HTML(f"<div><img src={img_url} width={width}><img src={img_url} width={width}></div>")
# Out:
# <div><img src=https://cards.scryfall.io/large/front/7/a/7a136f26-ac66-407f-b389-357222d2c4a2.jpg width=150><img src=https://cards.scryfall.io/large/front/7/a/7a136f26-ac66-407f-b389-357222d2c4a2.jpg width=150></div>

# %%
# Out:
# <img src=f"{img_url}"></img>
