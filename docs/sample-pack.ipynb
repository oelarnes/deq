# %%
from deq.sample_pack import get_sample_pack

# %%
p = get_sample_pack('FDN', filter_spec={'$and': [
    {'pick_num': 1},
    {'pack_num': 1},
    {'format_day': 3}
]})

# %%
from IPython.display import HTML
HTML(p.to_html())
# Out:
# <div class="draft-pack">
#     <div class="draft-pack-info-top">
#         <a href="https://17lands.com/draft/29d309ccc955495fa925ff115c3a86e1" class="draft-pack-17l-link">29d309ccc955495fa925ff115c3a86e1</a>
#         Record: 5 - 3
#     </div>
#     <div class="draft-pack-cards">
#         <img src="https://cards.scryfall.io/large/front/2/a/2ab0e660-86a3-4b92-82fa-77dcb5db947d.jpg" class="draft-pack-card">
#         <img src="https://cards.scryfall.io/large/front/0/1/0102e0be-5783-4825-9489-713b1b1df0b2.jpg" class="draft-pack-card">
#         <img src="https://cards.scryfall.io/large/front/6/e/6e5b899a-52f7-471b-ad50-4fa6566758fd.jpg" class="draft-pack-card">
#         <img src="https://cards.scryfall.io/large/front/1/c/1c4f7b20-b2a8-498c-8c36-dc296863b0b9.jpg" class="draft-pack-card">
#         <img src="https://cards.scryfall.io/large/front/9/6/96948ae3-b15d-4d6d-aa73-9f52084cd903.jpg" class="draft-pack-card">
# ...

# %%
from spells import summon
import polars as pl

from deq import ext
ata_v_gp = summon(["OTJ", "BLB", "FDN"]
                  
                  , ["ata", "gp_wr_17l"],
                  filter_spec={'player_cohort':"Top"},
                 extensions=ext).filter(
    pl.col("gp_wr_17l").is_not_null())

# %%
import matplotlib.pyplot as plt
_, ax = plt.subplots()

x = ata_v_gp["ata"]
y = ata_v_gp["gp_wr_17l"]
ax.scatter(x, y)

import numpy as np
m, b = np.polyfit(x, y, 1)
ax.plot(x, m*x+b, color="red")
print(m)

yr = y - m*x + b
np.sqrt(yr.var())
# Out:
# -0.0033591289829231173
# np.float64(0.013907110550526687)
