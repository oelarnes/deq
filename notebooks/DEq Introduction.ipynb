# %%
from spells import *
from deq import *
from spells.extension 
import *
from spells.config import *

# %%
all_sets
# Out:
# ['FDN',
#  'DSK',
#  'BLB',
#  'MH3',
#  'OTJ',
#  'MKM',
#  'LCI',
#  'WOE',
#  'LTR',
#  'MOM',
#  'ONE',
#  'BRO',
#  'DMU',
#  'SNC',
#  'NEO']
